# %% [markdown]
# The Complete Journey: All 30 Lessons
# MODULE 1: The Opening Whistle
#   Lesson 1:  What is Python
#   Lesson 2:  Jupyter Notebook
#   Lesson 3:  print()
#   Lesson 4:  Comments
#
# MODULE 2: Meet the Players
#   Lesson 5:  Variables
#   Lesson 6:  Strings
#   Lesson 7:  Integers and Floats
#   Lesson 8:  Booleans
#
# MODULE 3: The Rules of the Game
#   Lesson 9:  Arithmetic Operators
#   Lesson 10: Comparison Operators
#   Lesson 11: Logical Operators
#
# MODULE 4: Talking to the Crowd
#   Lesson 12: input()
#   Lesson 13: f-strings and Formatting
#   Lesson 14: Type Conversion
#
# MODULE 5: Match Tactics
#   Lesson 15: if
#   Lesson 16: else
#   Lesson 17: elif
#
# MODULE 6: Repetitive Drills
#   Lesson 18: while Loops
#   Lesson 19: for Loops with Lists
#   Lesson 20: range()
#
# MODULE 7: The Complete Squad
#   Lesson 21: Lists in Depth
#   Lesson 22: Tuples
#   Lesson 23: Dictionaries
#   Lesson 24: Nesting
#
# MODULE 8: Set Pieces
#   Lesson 25: Defining Functions
#   Lesson 26: Parameters and Arguments
#   Lesson 27: return
#
# MODULE 9: The Final Whistle
#   Lesson 28: Modules
#   Lesson 29: Penalty Shootout Simulator
#   Lesson 30: Next Steps
