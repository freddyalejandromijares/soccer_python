# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("STARTING ELEVEN — MANCHESTER CITY")
print("1.  Ederson")
print("2.  Kyle Walker")
print("3.  Ruben Dias")
print("4.  Manuel Akanji")
print("5.  Josko Gvardiol")
print("6.  Rodri")
print("7.  Kevin De Bruyne")
print("8.  Bernardo Silva")
print("9.  Phil Foden")
print("10. Jeremy Doku")
print("11. Erling Haaland")
# Out:
# STARTING ELEVEN — MANCHESTER CITY
# 1.  Ederson
# 2.  Kyle Walker
# 3.  Ruben Dias
# 4.  Manuel Akanji
# 5.  Josko Gvardiol
# 6.  Rodri
# 7.  Kevin De Bruyne
# 8.  Bernardo Silva
# 9.  Phil Foden
# 10. Jeremy Doku
# 11. Erling Haaland

# %%
print(9)      # Haaland's squad number
print(38)     # Matches in a Premier League season
print(97.4)   # A passing accuracy percentage
# Out:
# 9
# 38
# 97.4

# %%
print("Goals scored:", 3)
print("Goals conceded:", 1)
print("Shots on target:", 8)
print("Possession:", 62, "%")
# Out:
# Goals scored: 3
# Goals conceded: 1
# Shots on target: 8
# Possession: 62 %

# %%
print("FULL TIME RESULT")
print()
print("Tottenham Hotspur  2 — 3  Chelsea")
# Out:
# FULL TIME RESULT
#
# Tottenham Hotspur  2 — 3  Chelsea

# %%
print("=" * 40)
print("   PLAYER OF THE MATCH")
print("=" * 40)
print("   Bukayo Saka — Arsenal")
print("=" * 40)
# Out:
# ...
#    PLAYER OF THE MATCH
# ...
#    Bukayo Saka — Arsenal
# ...

# %%
# Default: space between items
print("Liverpool", "3", "Everton", "0")

# Custom separator: scoreboard style
print("Liverpool", "3", "Everton", "0", sep=" | ")

# Custom separator: dash style
print("Liverpool", "3", "Everton", "0", sep=" — ")
# Out:
# Liverpool 3 Everton 0
# Liverpool | 3 | Everton | 0
# Liverpool — 3 — Everton — 0

# %%
print("Checking VAR", end="")
print("... decision confirmed. GOAL STANDS!")
# Out:
# Checking VAR... decision confirmed. GOAL STANDS!

# %%
# Champions League Match Report
# Lesson 3 — Putting it all together

print("=" * 50)
print("   UEFA CHAMPIONS LEAGUE — GROUP STAGE")
print("   Matchday 6")
print("=" * 50)
print()
print("Real Madrid  vs  Borussia Dortmund")
print("Venue: Santiago Bernabeu  |  Att: 81,044")
print()
print("-" * 50)
print("GOALS")
print("-" * 50)
print("Vinicius Jr.     12'   (assist: Bellingham)")
print("Jude Bellingham  58'   (assist: Valverde)")
print("Donyell Malen    74'   (assist: Brandt)")
print()
print("-" * 50)
print("MATCH STATISTICS")
print("-" * 50)
print("Possession:    ", 64, "% vs", 36, "%")
print("Shots:         ", 14, "vs",  7)
print("Shots on tgt:  ", 6,  "vs",  3)
print("Corners:       ", 7,  "vs",  4)
print()
print("=" * 50)
print("FULL TIME:  Real Madrid  2 — 1  Dortmund")
print("=" * 50)
print()
print("Next match in", 7, "days")
# Out:
# ...
#    UEFA CHAMPIONS LEAGUE — GROUP STAGE
#    Matchday 6
# ...
#
# Real Madrid  vs  Borussia Dortmund
# Venue: Santiago Bernabeu  |  Att: 81,044
#
# --------------------------------------------------
# GOALS
# --------------------------------------------------
# Vinicius Jr.     12'   (assist: Bellingham)
# Jude Bellingham  58'   (assist: Valverde)
# Donyell Malen    74'   (assist: Brandt)
#
# --------------------------------------------------
# MATCH STATISTICS
# --------------------------------------------------
# Possession:     64 % vs 36 %
# Shots:          14 vs 7
# Shots on tgt:   6 vs 3
# Corners:        7 vs 4
#
# ...
# FULL TIME:  Real Madrid  2 — 1  Dortmund
# ...
#
# Next match in 7 days
