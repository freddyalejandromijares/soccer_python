# %% [markdown]
# # Lesson 2 — My Digital Stadium
# ## My first Jupyter Notebook
# *Welcome to the pitch.*

# %%
# Welcome message — this is a code cell
# The # symbol makes this line a comment. Python ignores it.

print("Stadium name: Wembley")
print("Capacity: 90,000")
print("Surface: Grass")
print("First match played here:", 1923)
# Out:
# Stadium name: Wembley
# Capacity: 90,000
# Surface: Grass
# First match played here: 1923

# %%
# Checking which teams are playing today
print("Home team: England")
print("Away team: France")
print("Competition: International Friendly")
print("=" * 35)
print("The match is about to begin!")
# Out:
# Home team: England
# Away team: France
# Competition: International Friendly
# ...
# The match is about to begin!
